# %% [markdown]
# <a href="https://colab.research.google.com/github/Mayurpro2/Data-analytics/blob/main/Professional_Data_Analytics_Portfolio.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 📊 Data Analytics Portfolio Project
#
# ## Professional Google Colab Notebook
#
# ### Project Overview
# This notebook demonstrates a complete end-to-end analytics workflow:
# - Data Loading
# - Data Cleaning
# - Exploratory Data Analysis (EDA)
# - KPI Development
# - Data Visualization
# - Business Insights
# - Recommendations
#
# **Tools:** Python, Pandas, NumPy, Matplotlib

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

print("Libraries loaded successfully")
# Out:
# Libraries loaded successfully

# %% [markdown]
# ## Load Dataset

# %%
# Replace with your dataset
# df = pd.read_csv('/content/dataset.csv')

print("Upload your dataset and uncomment the line above.")
# Out:
# Upload your dataset and uncomment the line above.

# %% [markdown]
# ## Data Quality Checks

# %%
# Example commands
# df.info()
# df.describe()
# df.isnull().sum()

# %% [markdown]
# ## Data Cleaning

# %%
# df.drop_duplicates(inplace=True)
# df.fillna(0, inplace=True)

# %% [markdown]
# ## Exploratory Data Analysis

# %%
# Example:
# df.head()

# %% [markdown]
# ## KPI Calculations

# %%
# total_sales = df['Sales'].sum()
# total_profit = df['Profit'].sum()

# print(total_sales, total_profit)

# %% [markdown]
# ## Visualizations

# %%
# Example visualization
# df.groupby('Category')['Sales'].sum().plot(kind='bar')
# plt.title('Sales by Category')
# plt.show()

# %% [markdown]
# ## Business Insights
#
# - Identify top-performing categories
# - Analyze customer behavior
# - Track revenue and profitability
# - Support decision-making through data
#
# ## Recommendations
#
# 1. Focus on high-performing segments.
# 2. Improve underperforming areas.
# 3. Monitor KPIs regularly.
# 4. Automate reporting workflows.
